# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/tylermurray/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sid = SentimentIntensityAnalyzer()

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('../Project-02/Project 2 Sentiment Data - Ethereum.csv')
df.head()
# Out:
#    Title  Sentiment                                            Comment
# 0      1        0.0  All the tosspots focusing on Vitaliks wealth c...
# 1      2        NaN                                                NaN
# 2      3        NaN                                                NaN
# 3      4        0.0                              Too many trolls here.
# 4      5        NaN                                                NaN

# %%
df['Title'].value_counts()
# Out:
# 904    1
# 283    1
# 309    1
# 308    1
# 307    1
#       ..
# 599    1
# 598    1
# 597    1
# 596    1
# 1      1
# Name: Title, Length: 904, dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#     Title  Sentiment                                            Comment
# 0       1        0.0  All the tosspots focusing on Vitaliks wealth c...
# 3       4        0.0                              Too many trolls here.
# 6       7        0.0  * Price information is currently the most tran...
# 26     27        0.0  Everyone here seems to be of the mind *"Well h...
# 39     40        0.0                    Respect for him for doing this!

# %%
df['scores'] = df['Comment'].apply(lambda review: sid.polarity_scores(review))

df.head()
# Out:
#     Title  Sentiment                                            Comment  \
# 0       1        0.0  All the tosspots focusing on Vitaliks wealth c...
# 3       4        0.0                              Too many trolls here.
# 6       7        0.0  * Price information is currently the most tran...
# 26     27        0.0  Everyone here seems to be of the mind *"Well h...
# 39     40        0.0                    Respect for him for doing this!
#
#                                                scores
# 0   {'neg': 0.134, 'neu': 0.639, 'pos': 0.227, 'co...
# 3   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 6   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 26  {'neg': 0.0, 'neu': 0.816, 'pos': 0.184, 'comp...
# 39  {'neg': 0.0, 'neu': 0.596, 'pos': 0.404, 'comp...

# %%
df['compound']  = df['scores'].apply(lambda score_dict: score_dict['compound'])

df.head()
# Out:
#     Title  Sentiment                                            Comment  \
# 0       1        0.0  All the tosspots focusing on Vitaliks wealth c...
# 3       4        0.0                              Too many trolls here.
# 6       7        0.0  * Price information is currently the most tran...
# 26     27        0.0  Everyone here seems to be of the mind *"Well h...
# 39     40        0.0                    Respect for him for doing this!
#
#                                                scores  compound
# 0   {'neg': 0.134, 'neu': 0.639, 'pos': 0.227, 'co...    0.3197
# 3   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 6   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 26  {'neg': 0.0, 'neu': 0.816, 'pos': 0.184, 'comp...    0.5574
# 39  {'neg': 0.0, 'neu': 0.596, 'pos': 0.404, 'comp...    0.5255

# %%
df['comp_score'] = df['compound'].apply(lambda c: 'pos' if c >=0 else 'neg')

df.head()
# Out:
#     Title  Sentiment                                            Comment  \
# 0       1        0.0  All the tosspots focusing on Vitaliks wealth c...
# 3       4        0.0                              Too many trolls here.
# 6       7        0.0  * Price information is currently the most tran...
# 26     27        0.0  Everyone here seems to be of the mind *"Well h...
# 39     40        0.0                    Respect for him for doing this!
#
#                                                scores  compound comp_score
# 0   {'neg': 0.134, 'neu': 0.639, 'pos': 0.227, 'co...    0.3197        pos
# 3   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000        pos
# 6   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000        pos
# 26  {'neg': 0.0, 'neu': 0.816, 'pos': 0.184, 'comp...    0.5574        pos
# 39  {'neg': 0.0, 'neu': 0.596, 'pos': 0.404, 'comp...    0.5255        pos
