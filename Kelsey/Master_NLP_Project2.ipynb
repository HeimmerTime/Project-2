# %%
# Initial imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from pathlib import Path

# %matplotlib inline
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\Kelsey\anaconda3\envs\pyvizenv\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
from numpy.random import seed
seed(1)

from tensorflow import random
random.set_seed(2)

# %%
# Import the dataset
file_path = Path("../Kelsey/ETH_Bull.csv")
eth_bull_news_df = pd.read_csv(file_path, index_col = 'date', parse_dates=True, infer_datetime_format=True)
eth_bull_news_df = eth_bull_news_df.sort_index()
eth_bull_news_df
# Out:
#                                                          text  compound  \
# date
# 0001-01-01  Ethereum is an open-source, public, blockchain...    0.6369
# 0001-01-01  Ethereum is an open-source, public, blockchain...    0.6369
# 0001-01-01  Ethereum is an open-source, public, blockchain...    0.6369
# 0001-01-01  Ethereum is an open-source, public, blockchain...    0.6369
# 0001-01-01  Ethereum is an open-source, public, blockchain...    0.6369
# 0001-01-01  Ethereum is an open-source, public, blockchain...    0.6369
# 0001-01-01  Ethereum is an open-source, public, blockchain...    0.6369
# 0001-01-01  Ethereum is an open-source, public, blockchain...    0.6369
# 0001-01-01  Ethereum is an open-source, public, blockchain...    0.6369
# 2021-01-19  ALQO Hits Market Cap of $2.52 Million (XLQ)\nP...    0.3680
# 2021-01-20  Jan 20, 2021 at 12:30 p.m. UTC\nValid Points: ...    0.9961
# 2021-01-20  Asias biggest Ethereum wallet imToken integrat...    0.9942
# 2021-01-20  ) notched a new record on Tuesday: $1,439.33, ...    0.9977
# 2021-01-20  14:17 GMT\nEthereum price was rejected at its ...   -0.8866
# 2021-01-20  Tweet\neosDAC (CURRENCY:EOSDAC) traded down 2....    0.7125
# 2021-01-20  VBK\nis a PoP + PoW coin that uses the vBlake ...    0.9730
# 2021-01-20  ETH has broken its previous ATH.\nDeFi and net...    0.9986
# 2021-01-20  Polkadot price expected to retest 17.50\nThe c...    0.9889
# 2021-01-20  Bitcoin slips to $34,832 with 6pc fall\nJanuar...   -0.3453
# 2021-01-20  Tether Use on Tron Passes Ethereum as Low Fees...    0.9892
# 2021-01-20  DeFi assets DAI and WBTC added to the BitPay W...    0.9781
# 2021-01-21  .\nEthereum prepares for liftoff to $1,700 ahe...    0.9270
# 2021-01-21  Tweet\nMyriad (CURRENCY:XMY) traded 19.9% lowe...    0.3885
# 2021-01-21  10:37 GMT\nBitcoin reacts to a symmetrical tri...    0.9700
# 2021-01-21  Tweet\nSwitch (CURRENCY:ESH) traded 10.2% lowe...   -0.4708
# 2021-01-21  Moonbeam upgrades Polkadot smart contract plat...    0.9936
# 2021-01-21  Messenger\nThe price of the worlds second larg...    0.9976
# 2021-01-21  Tweet\nQuark (CURRENCY:QRK) traded down 22% ag...    0.4084
# 2021-01-21  Naver\nEthereum price rose to $ 420 thousand o...   -0.4840
# 2021-01-21  inside ourselves and out at the world\nIndepen...    0.8225
# ...                                                       ...       ...
# 2021-04-21  ICX\nis a LFT coin that uses the Loopchain has...    0.9052
# 2021-04-22  Tweet\nFractal (CURRENCY:FCL) traded 0.7% lowe...   -0.5672
# 2021-04-22  ICON (ICX)\nis a LFT coin that uses the Loopch...    0.9052
# 2021-04-22  Tweet\nOptionRoom (CURRENCY:ROOM) traded 6.3% ...   -0.6448
# 2021-04-23  Tweet\nPolkamon (CURRENCY:PMON) traded down 23...   -0.6448
# 2021-04-23  Tweet\nGrimm (CURRENCY:GRIMM) traded up 118.5%...    0.8918
# 2021-04-23  Tweet\nVIG (CURRENCY:VIG) traded 5.7% lower ag...    0.3680
# 2021-04-23  Tweet\nRatecoin (CURRENCY:XRA) traded 10.4% lo...    0.4824
# 2021-04-23  Tweet\nFractal (CURRENCY:FCL) traded down 17.6...   -0.3542
# 2021-04-23  Tweet\nNibble (CURRENCY:NBXC) traded down 49.9...    0.6037
# 2021-05-05  Tweet\nStakedZEN (CURRENCY:STZEN) traded 1.9% ...    0.3680
# 2021-05-05  Grimm (GRIMM) Hits Market Cap of $208,456.34\n...    0.4995
# 2021-05-05  Tweet\nStakedZEN (CURRENCY:STZEN) traded 1.9% ...    0.3680
# 2021-05-05  Grimm (GRIMM) Hits Market Cap of $208,456.34\n...    0.4995
# 2021-05-07  Tweet\nAitra (CURRENCY:AITRA) traded 3.8% high...    0.0857
# 2021-05-07  Tweet\nOptionRoom (CURRENCY:ROOM) traded down ...   -0.4708
# 2021-05-07  BiblePay (CRYPTO:BBP)\nis a POBh coin that use...    0.6037
# 2021-05-07  BiblePay (CRYPTO:BBP)\nis a POBh coin that use...    0.6037
# 2021-05-07  Gridcoin (CRYPTO:GRC)\nis a DPoR coin that use...   -0.3184
# 2021-05-07  Tweet\nAitra (CURRENCY:AITRA) traded 3.8% high...    0.0857
# 2021-05-07  Tweet\nOptionRoom (CURRENCY:ROOM) traded down ...   -0.4708
# 2021-05-07  Gridcoin (CRYPTO:GRC)\nis a DPoR coin that use...   -0.3184
# 2021-05-08  Ethereum Climbs 10% In a Green Day\nInvesting....    0.9217
# 2021-05-08  Ethereum Climbs 10% In a Green Day\nInvesting....    0.9217
# 2021-05-09  SCRIV\nis a PoW + Masternodes coin that uses t...    0.8964
# 2021-05-09  GRC\nis a DPoR coin that uses the ProofofResea...   -0.3184
# 2021-05-09  Gridcoin (GRC)\nis a DPoR coin that uses the P...   -0.3184
# 2021-05-09  SCRIV\nis a PoW + Masternodes coin that uses t...    0.8964
# 2021-05-09  GRC\nis a DPoR coin that uses the ProofofResea...   -0.3184
# 2021-05-09  Gridcoin (GRC)\nis a DPoR coin that uses the P...   -0.3184
#
#             positive  negative  neutral
# date
# 0001-01-01     0.161     0.000    0.839
# 0001-01-01     0.161     0.000    0.839
# 0001-01-01     0.161     0.000    0.839
# 0001-01-01     0.161     0.000    0.839
# 0001-01-01     0.161     0.000    0.839
# 0001-01-01     0.161     0.000    0.839
# 0001-01-01     0.161     0.000    0.839
# 0001-01-01     0.161     0.000    0.839
# 0001-01-01     0.161     0.000    0.839
# 2021-01-19     0.016     0.012    0.972
# 2021-01-20     0.086     0.020    0.893
# 2021-01-20     0.122     0.022    0.857
# 2021-01-20     0.104     0.024    0.872
# 2021-01-20     0.071     0.091    0.838
# 2021-01-20     0.017     0.000    0.983
# 2021-01-20     0.106     0.000    0.894
# 2021-01-20     0.210     0.013    0.777
# 2021-01-20     0.085     0.040    0.876
# 2021-01-20     0.076     0.080    0.844
# 2021-01-20     0.099     0.016    0.885
# 2021-01-20     0.115     0.000    0.885
# 2021-01-21     0.087     0.071    0.843
# 2021-01-21     0.035     0.030    0.935
# 2021-01-21     0.094     0.069    0.836
# 2021-01-21     0.015     0.028    0.956
# 2021-01-21     0.172     0.006    0.823
# 2021-01-21     0.112     0.037    0.851
# 2021-01-21     0.023     0.018    0.958
# 2021-01-21     0.059     0.060    0.881
# 2021-01-21     0.118     0.000    0.882
# ...              ...       ...      ...
# 2021-04-21     0.057     0.000    0.943
# 2021-04-22     0.023     0.041    0.937
# 2021-04-22     0.057     0.000    0.943
# 2021-04-22     0.016     0.036    0.948
# 2021-04-23     0.016     0.035    0.950
# 2021-04-23     0.030     0.000    0.970
# 2021-04-23     0.016     0.015    0.969
# 2021-04-23     0.025     0.019    0.956
# 2021-04-23     0.023     0.035    0.942
# 2021-04-23     0.023     0.012    0.964
# 2021-05-05     0.016     0.012    0.971
# 2021-05-05     0.023     0.017    0.959
# 2021-05-05     0.016     0.012    0.971
# 2021-05-05     0.023     0.017    0.959
# 2021-05-07     0.016     0.017    0.967
# 2021-05-07     0.016     0.030    0.953
# 2021-05-07     0.020     0.006    0.974
# 2021-05-07     0.020     0.006    0.974
# 2021-05-07     0.036     0.044    0.920
# 2021-05-07     0.016     0.017    0.967
# 2021-05-07     0.016     0.030    0.953
# 2021-05-07     0.036     0.044    0.920
# 2021-05-08     0.064     0.000    0.936
# 2021-05-08     0.064     0.000    0.936
# 2021-05-09     0.053     0.000    0.947
# 2021-05-09     0.036     0.044    0.920
# 2021-05-09     0.035     0.044    0.921
# 2021-05-09     0.053     0.000    0.947
# 2021-05-09     0.036     0.044    0.920
# 2021-05-09     0.035     0.044    0.921
#
# [504 rows x 5 columns]

# %%
eth_bull_news_df.insert(5, 'market', 'Bull')
eth_bull_news_df.head()
# Out:
#                                                          text  compound  \
# date
# 0001-01-01  Ethereum is an open-source, public, blockchain...    0.6369
# 0001-01-01  Ethereum is an open-source, public, blockchain...    0.6369
# 0001-01-01  Ethereum is an open-source, public, blockchain...    0.6369
# 0001-01-01  Ethereum is an open-source, public, blockchain...    0.6369
# 0001-01-01  Ethereum is an open-source, public, blockchain...    0.6369
#
#             positive  negative  neutral market
# date
# 0001-01-01     0.161       0.0    0.839   Bull
# 0001-01-01     0.161       0.0    0.839   Bull
# 0001-01-01     0.161       0.0    0.839   Bull
# 0001-01-01     0.161       0.0    0.839   Bull
# 0001-01-01     0.161       0.0    0.839   Bull

# %%
# Import the dataset
file_path = Path("../Kelsey/ETH_Bear.csv")
eth_bear_news_df = pd.read_csv(file_path, index_col = 'date', parse_dates=True, infer_datetime_format=True)
eth_bear_news_df = eth_bear_news_df.sort_index()
eth_bear_news_df.head()
# Out:
#                                                          text  compound  \
# date
# 0001-01-01  Ethereum is an open-source, public, blockchain...    0.6369
# 0001-01-01  Ethereum is an open-source, public, blockchain...    0.6369
# 0001-01-01  Ethereum is an open-source, public, blockchain...    0.6369
# 0001-01-01  Ethereum is an open-source, public, blockchain...    0.6369
# 0001-01-01  Ethereum is an open-source, public, blockchain...    0.6369
#
#             positive  negative  neutral
# date
# 0001-01-01     0.161       0.0    0.839
# 0001-01-01     0.161       0.0    0.839
# 0001-01-01     0.161       0.0    0.839
# 0001-01-01     0.161       0.0    0.839
# 0001-01-01     0.161       0.0    0.839

# %%
eth_bear_news_df.insert(5, 'market', 'Bear')
eth_bear_news_df.head()
# Out:
#                                                          text  compound  \
# date
# 0001-01-01  Ethereum is an open-source, public, blockchain...    0.6369
# 0001-01-01  Ethereum is an open-source, public, blockchain...    0.6369
# 0001-01-01  Ethereum is an open-source, public, blockchain...    0.6369
# 0001-01-01  Ethereum is an open-source, public, blockchain...    0.6369
# 0001-01-01  Ethereum is an open-source, public, blockchain...    0.6369
#
#             positive  negative  neutral market
# date
# 0001-01-01     0.161       0.0    0.839   Bear
# 0001-01-01     0.161       0.0    0.839   Bear
# 0001-01-01     0.161       0.0    0.839   Bear
# 0001-01-01     0.161       0.0    0.839   Bear
# 0001-01-01     0.161       0.0    0.839   Bear

# %%
eth_news_combined = pd.concat([eth_bull_news_df, eth_bear_news_df], axis="rows", join="inner")
eth_news_combined
# Out:
#                                                          text  compound  \
# date
# 0001-01-01  Ethereum is an open-source, public, blockchain...    0.6369
# 0001-01-01  Ethereum is an open-source, public, blockchain...    0.6369
# 0001-01-01  Ethereum is an open-source, public, blockchain...    0.6369
# 0001-01-01  Ethereum is an open-source, public, blockchain...    0.6369
# 0001-01-01  Ethereum is an open-source, public, blockchain...    0.6369
# 0001-01-01  Ethereum is an open-source, public, blockchain...    0.6369
# 0001-01-01  Ethereum is an open-source, public, blockchain...    0.6369
# 0001-01-01  Ethereum is an open-source, public, blockchain...    0.6369
# 0001-01-01  Ethereum is an open-source, public, blockchain...    0.6369
# 2021-01-19  ALQO Hits Market Cap of $2.52 Million (XLQ)\nP...    0.3680
# 2021-01-20  Jan 20, 2021 at 12:30 p.m. UTC\nValid Points: ...    0.9961
# 2021-01-20  Asias biggest Ethereum wallet imToken integrat...    0.9942
# 2021-01-20  ) notched a new record on Tuesday: $1,439.33, ...    0.9977
# 2021-01-20  14:17 GMT\nEthereum price was rejected at its ...   -0.8866
# 2021-01-20  Tweet\neosDAC (CURRENCY:EOSDAC) traded down 2....    0.7125
# 2021-01-20  VBK\nis a PoP + PoW coin that uses the vBlake ...    0.9730
# 2021-01-20  ETH has broken its previous ATH.\nDeFi and net...    0.9986
# 2021-01-20  Polkadot price expected to retest 17.50\nThe c...    0.9889
# 2021-01-20  Bitcoin slips to $34,832 with 6pc fall\nJanuar...   -0.3453
# 2021-01-20  Tether Use on Tron Passes Ethereum as Low Fees...    0.9892
# 2021-01-20  DeFi assets DAI and WBTC added to the BitPay W...    0.9781
# 2021-01-21  .\nEthereum prepares for liftoff to $1,700 ahe...    0.9270
# 2021-01-21  Tweet\nMyriad (CURRENCY:XMY) traded 19.9% lowe...    0.3885
# 2021-01-21  10:37 GMT\nBitcoin reacts to a symmetrical tri...    0.9700
# 2021-01-21  Tweet\nSwitch (CURRENCY:ESH) traded 10.2% lowe...   -0.4708
# 2021-01-21  Moonbeam upgrades Polkadot smart contract plat...    0.9936
# 2021-01-21  Messenger\nThe price of the worlds second larg...    0.9976
# 2021-01-21  Tweet\nQuark (CURRENCY:QRK) traded down 22% ag...    0.4084
# 2021-01-21  Naver\nEthereum price rose to $ 420 thousand o...   -0.4840
# 2021-01-21  inside ourselves and out at the world\nIndepen...    0.8225
# ...                                                       ...       ...
# 2021-07-12  TrendSpider\nEthereum is the next largest cryp...    0.9732
# 2021-07-12  ) and Ethereum) designed to directly compete w...    0.9778
# 2021-07-12  Pile of silver bitcoins. Creative background. ...    0.9869
# 2021-07-12  WAX\nHedera Hashgraph\nSome of these blockchai...    0.9957
# 2021-07-12  WAX\nHedera Hashgraph\nSome of these blockchai...    0.9961
# 2021-07-12  Editor\nUpdated: Jul 12, 2021, 11:49am\nEditor...    0.9942
# 2021-07-12  Image source: Getty Images.\nSo what\nWhy is t...   -0.1258
# 2021-07-13  /PRNewswire/ -- RedStone, the creator of a nex...    0.9644
# 2021-07-13  Share on Stocktwits\nZooKeeper (CURRENCY:ZOO) ...    0.2342
# 2021-07-13  The global cryptocurrency market capitalizatio...   -0.0516
# 2021-07-13  Share on Stocktwits\nKineko (CURRENCY:KKO) tra...    0.2342
# 2021-07-13  Your ability to comment is currently suspended...    0.9719
# 2021-07-13  Fake Tesla, Apple stocks have started trading ...    0.9784
# 2021-07-13  Your ability to comment is currently suspended...    0.9719
# 2021-07-13  Dogecoin and cryptocurrency value surge after ...    0.9810
# 2021-07-13  Binance Coin Price Up By 5.12%  Time To Buy BN...    0.9822
# 2021-07-13  For many people, a popular way to obtain Ether...    0.9714
# 2021-07-13  BiblePay\nis a POBh coin that uses the Proof-o...    0.6037
# 2021-07-13  Ethereums DeFi dominance\n), expectations run ...    0.9980
# 2021-07-13  is doing worst of all -- down 3.7%.\nSo what\n...    0.9739
# 2021-07-13  0\nNFTs are all the rage so in turn it greatly...    0.9909
# 2021-07-13  If youre new to the world of cryptocurrencies,...    0.9984
# 2021-07-13  Share on Stocktwits\nNFT Alley (CURRENCY:ALLEY...    0.4824
# 2021-07-13  Share on Stocktwits\nHavy (CURRENCY:HAVY) trad...    0.5766
# 2021-07-13  Smooth Love Potion Price is Surging Here is Wh...    0.9926
# 2021-07-13  Share on Stocktwits\nSaito (CURRENCY:SAITO) tr...    0.0857
# 2021-07-13  Share on Stocktwits\nLCMS (CURRENCY:LCMS) trad...   -0.2185
# 2021-07-13  ZRX\n) decentralized exchange (DEX) protocol h...    0.7003
# 2021-07-13  Bitcoin advocate Jack Dorsey says his payment ...    0.0379
# 2021-07-13  ZRX\n) decentralized exchange (DEX) protocol h...    0.7003
#
#             positive  negative  neutral market
# date
# 0001-01-01     0.161     0.000    0.839   Bull
# 0001-01-01     0.161     0.000    0.839   Bull
# 0001-01-01     0.161     0.000    0.839   Bull
# 0001-01-01     0.161     0.000    0.839   Bull
# 0001-01-01     0.161     0.000    0.839   Bull
# 0001-01-01     0.161     0.000    0.839   Bull
# 0001-01-01     0.161     0.000    0.839   Bull
# 0001-01-01     0.161     0.000    0.839   Bull
# 0001-01-01     0.161     0.000    0.839   Bull
# 2021-01-19     0.016     0.012    0.972   Bull
# 2021-01-20     0.086     0.020    0.893   Bull
# 2021-01-20     0.122     0.022    0.857   Bull
# 2021-01-20     0.104     0.024    0.872   Bull
# 2021-01-20     0.071     0.091    0.838   Bull
# 2021-01-20     0.017     0.000    0.983   Bull
# 2021-01-20     0.106     0.000    0.894   Bull
# 2021-01-20     0.210     0.013    0.777   Bull
# 2021-01-20     0.085     0.040    0.876   Bull
# 2021-01-20     0.076     0.080    0.844   Bull
# 2021-01-20     0.099     0.016    0.885   Bull
# 2021-01-20     0.115     0.000    0.885   Bull
# 2021-01-21     0.087     0.071    0.843   Bull
# 2021-01-21     0.035     0.030    0.935   Bull
# 2021-01-21     0.094     0.069    0.836   Bull
# 2021-01-21     0.015     0.028    0.956   Bull
# 2021-01-21     0.172     0.006    0.823   Bull
# 2021-01-21     0.112     0.037    0.851   Bull
# 2021-01-21     0.023     0.018    0.958   Bull
# 2021-01-21     0.059     0.060    0.881   Bull
# 2021-01-21     0.118     0.000    0.882   Bull
# ...              ...       ...      ...    ...
# 2021-07-12     0.142     0.055    0.803   Bear
# 2021-07-12     0.072     0.012    0.916   Bear
# 2021-07-12     0.114     0.006    0.881   Bear
# 2021-07-12     0.137     0.000    0.863   Bear
# 2021-07-12     0.130     0.000    0.870   Bear
# 2021-07-12     0.094     0.041    0.865   Bear
# 2021-07-12     0.079     0.084    0.838   Bear
# 2021-07-13     0.063     0.025    0.913   Bear
# 2021-07-13     0.029     0.029    0.942   Bear
# 2021-07-13     0.018     0.021    0.962   Bear
# 2021-07-13     0.028     0.029    0.943   Bear
# 2021-07-13     0.247     0.050    0.703   Bear
# 2021-07-13     0.101     0.063    0.836   Bear
# 2021-07-13     0.247     0.050    0.703   Bear
# 2021-07-13     0.111     0.022    0.867   Bear
# 2021-07-13     0.092     0.038    0.870   Bear
# 2021-07-13     0.084     0.024    0.892   Bear
# 2021-07-13     0.021     0.006    0.974   Bear
# 2021-07-13     0.123     0.056    0.821   Bear
# 2021-07-13     0.121     0.071    0.807   Bear
# 2021-07-13     0.082     0.016    0.901   Bear
# 2021-07-13     0.204     0.018    0.778   Bear
# 2021-07-13     0.027     0.022    0.950   Bear
# 2021-07-13     0.021     0.012    0.967   Bear
# 2021-07-13     0.140     0.015    0.845   Bear
# 2021-07-13     0.021     0.023    0.956   Bear
# 2021-07-13     0.022     0.029    0.949   Bear
# 2021-07-13     0.130     0.117    0.754   Bear
# 2021-07-13     0.041     0.041    0.918   Bear
# 2021-07-13     0.130     0.117    0.754   Bear
#
# [1191 rows x 6 columns]

# %%
# Drop first row
# by selecting all rows from first row onwards
eth_news_combined = eth_news_combined.iloc[9: , :]
eth_news_combined
# Out:
#                                                          text  compound  \
# date
# 2021-01-20  Bitcoin slips to $34,832 with 6pc fall\nJanuar...   -0.3453
# 2021-01-20  Tether Use on Tron Passes Ethereum as Low Fees...    0.9892
# 2021-01-20  DeFi assets DAI and WBTC added to the BitPay W...    0.9781
# 2021-01-21  .\nEthereum prepares for liftoff to $1,700 ahe...    0.9270
# 2021-01-21  Tweet\nMyriad (CURRENCY:XMY) traded 19.9% lowe...    0.3885
# 2021-01-21  10:37 GMT\nBitcoin reacts to a symmetrical tri...    0.9700
# 2021-01-21  Tweet\nSwitch (CURRENCY:ESH) traded 10.2% lowe...   -0.4708
# 2021-01-21  Moonbeam upgrades Polkadot smart contract plat...    0.9936
# 2021-01-21  Messenger\nThe price of the worlds second larg...    0.9976
# 2021-01-21  Tweet\nQuark (CURRENCY:QRK) traded down 22% ag...    0.4084
# 2021-01-21  Naver\nEthereum price rose to $ 420 thousand o...   -0.4840
# 2021-01-21  inside ourselves and out at the world\nIndepen...    0.8225
# 2021-01-22  Tweet\nBolivarcoin (CURRENCY:BOLI) traded down...    0.4824
# 2021-01-22  Bitcoin bounces off support at $30,000 as a do...    0.2846
# 2021-01-22  Disclaimer\nNote: All information on this page...   -0.2373
# 2021-01-22  Garlicoin (GRLC)\nis a Scrypt-adaptive-N (ASIC...    0.2577
# 2021-01-22  VeriBlock (VBK)\nis a PoP + PoW coin that uses...    0.9730
# 2021-01-23  Tweet\nPRIZM (CURRENCY:PZM) traded up 3.3% aga...    0.5766
# 2021-01-23  Tweet\nManna (CURRENCY:MANNA) traded 0.9% lowe...    0.9554
# 2021-01-23  Frothy Squared: Crypto Firms Are Lining Up to ...    0.9970
# 2021-01-23  Tweet\nSora (CURRENCY:XOR) traded 3.7% higher ...    0.3680
# 2021-01-23  Tweet\nPeercoin (CURRENCY:PPC) traded down 1.8...    0.3680
# 2021-01-24  Tweet\nGossip Coin (CURRENCY:GOSS) traded down...   -0.9309
# 2021-01-24  Please opt-in to receive news and information ...    0.9496
# 2021-01-24  Bitcoin plunges over 1pc to $32,131\nJanuary 2...    0.8616
# 2021-01-24  ETH/USD awaits a fresh catalyst for the next p...    0.7506
# 2021-01-24  Garlicoin\nis a Scrypt-adaptive-N (ASIC resist...    0.2577
# 2021-01-24  Kcash\nis a Zero-Knowledge Proof token that us...    0.9672
# 2021-01-24  Lunes (LUNES)\nis a LPoS coin that uses the Le...    0.9265
# 2021-01-24  Tweet\nSora (CURRENCY:XOR) traded 7.4% higher ...    0.7125
# ...                                                       ...       ...
# 2021-07-12  TrendSpider\nEthereum is the next largest cryp...    0.9732
# 2021-07-12  ) and Ethereum) designed to directly compete w...    0.9778
# 2021-07-12  Pile of silver bitcoins. Creative background. ...    0.9869
# 2021-07-12  WAX\nHedera Hashgraph\nSome of these blockchai...    0.9957
# 2021-07-12  WAX\nHedera Hashgraph\nSome of these blockchai...    0.9961
# 2021-07-12  Editor\nUpdated: Jul 12, 2021, 11:49am\nEditor...    0.9942
# 2021-07-12  Image source: Getty Images.\nSo what\nWhy is t...   -0.1258
# 2021-07-13  /PRNewswire/ -- RedStone, the creator of a nex...    0.9644
# 2021-07-13  Share on Stocktwits\nZooKeeper (CURRENCY:ZOO) ...    0.2342
# 2021-07-13  The global cryptocurrency market capitalizatio...   -0.0516
# 2021-07-13  Share on Stocktwits\nKineko (CURRENCY:KKO) tra...    0.2342
# 2021-07-13  Your ability to comment is currently suspended...    0.9719
# 2021-07-13  Fake Tesla, Apple stocks have started trading ...    0.9784
# 2021-07-13  Your ability to comment is currently suspended...    0.9719
# 2021-07-13  Dogecoin and cryptocurrency value surge after ...    0.9810
# 2021-07-13  Binance Coin Price Up By 5.12%  Time To Buy BN...    0.9822
# 2021-07-13  For many people, a popular way to obtain Ether...    0.9714
# 2021-07-13  BiblePay\nis a POBh coin that uses the Proof-o...    0.6037
# 2021-07-13  Ethereums DeFi dominance\n), expectations run ...    0.9980
# 2021-07-13  is doing worst of all -- down 3.7%.\nSo what\n...    0.9739
# 2021-07-13  0\nNFTs are all the rage so in turn it greatly...    0.9909
# 2021-07-13  If youre new to the world of cryptocurrencies,...    0.9984
# 2021-07-13  Share on Stocktwits\nNFT Alley (CURRENCY:ALLEY...    0.4824
# 2021-07-13  Share on Stocktwits\nHavy (CURRENCY:HAVY) trad...    0.5766
# 2021-07-13  Smooth Love Potion Price is Surging Here is Wh...    0.9926
# 2021-07-13  Share on Stocktwits\nSaito (CURRENCY:SAITO) tr...    0.0857
# 2021-07-13  Share on Stocktwits\nLCMS (CURRENCY:LCMS) trad...   -0.2185
# 2021-07-13  ZRX\n) decentralized exchange (DEX) protocol h...    0.7003
# 2021-07-13  Bitcoin advocate Jack Dorsey says his payment ...    0.0379
# 2021-07-13  ZRX\n) decentralized exchange (DEX) protocol h...    0.7003
#
#             positive  negative  neutral market
# date
# 2021-01-20     0.076     0.080    0.844   Bull
# 2021-01-20     0.099     0.016    0.885   Bull
# 2021-01-20     0.115     0.000    0.885   Bull
# 2021-01-21     0.087     0.071    0.843   Bull
# 2021-01-21     0.035     0.030    0.935   Bull
# 2021-01-21     0.094     0.069    0.836   Bull
# 2021-01-21     0.015     0.028    0.956   Bull
# 2021-01-21     0.172     0.006    0.823   Bull
# 2021-01-21     0.112     0.037    0.851   Bull
# 2021-01-21     0.023     0.018    0.958   Bull
# 2021-01-21     0.059     0.060    0.881   Bull
# 2021-01-21     0.118     0.000    0.882   Bull
# 2021-01-22     0.026     0.019    0.955   Bull
# 2021-01-22     0.076     0.073    0.851   Bull
# 2021-01-22     0.083     0.086    0.831   Bull
# 2021-01-22     0.033     0.028    0.939   Bull
# 2021-01-22     0.107     0.000    0.893   Bull
# 2021-01-23     0.018     0.007    0.976   Bull
# 2021-01-23     0.062     0.012    0.925   Bull
# 2021-01-23     0.097     0.028    0.875   Bull
# 2021-01-23     0.017     0.013    0.970   Bull
# 2021-01-23     0.017     0.013    0.970   Bull
# 2021-01-24     0.022     0.098    0.880   Bull
# 2021-01-24     0.069     0.000    0.931   Bull
# 2021-01-24     0.178     0.052    0.770   Bull
# 2021-01-24     0.072     0.058    0.870   Bull
# 2021-01-24     0.033     0.028    0.939   Bull
# 2021-01-24     0.079     0.000    0.921   Bull
# 2021-01-24     0.067     0.000    0.933   Bull
# 2021-01-24     0.030     0.017    0.952   Bull
# ...              ...       ...      ...    ...
# 2021-07-12     0.142     0.055    0.803   Bear
# 2021-07-12     0.072     0.012    0.916   Bear
# 2021-07-12     0.114     0.006    0.881   Bear
# 2021-07-12     0.137     0.000    0.863   Bear
# 2021-07-12     0.130     0.000    0.870   Bear
# 2021-07-12     0.094     0.041    0.865   Bear
# 2021-07-12     0.079     0.084    0.838   Bear
# 2021-07-13     0.063     0.025    0.913   Bear
# 2021-07-13     0.029     0.029    0.942   Bear
# 2021-07-13     0.018     0.021    0.962   Bear
# 2021-07-13     0.028     0.029    0.943   Bear
# 2021-07-13     0.247     0.050    0.703   Bear
# 2021-07-13     0.101     0.063    0.836   Bear
# 2021-07-13     0.247     0.050    0.703   Bear
# 2021-07-13     0.111     0.022    0.867   Bear
# 2021-07-13     0.092     0.038    0.870   Bear
# 2021-07-13     0.084     0.024    0.892   Bear
# 2021-07-13     0.021     0.006    0.974   Bear
# 2021-07-13     0.123     0.056    0.821   Bear
# 2021-07-13     0.121     0.071    0.807   Bear
# 2021-07-13     0.082     0.016    0.901   Bear
# 2021-07-13     0.204     0.018    0.778   Bear
# 2021-07-13     0.027     0.022    0.950   Bear
# 2021-07-13     0.021     0.012    0.967   Bear
# 2021-07-13     0.140     0.015    0.845   Bear
# 2021-07-13     0.021     0.023    0.956   Bear
# 2021-07-13     0.022     0.029    0.949   Bear
# 2021-07-13     0.130     0.117    0.754   Bear
# 2021-07-13     0.041     0.041    0.918   Bear
# 2021-07-13     0.130     0.117    0.754   Bear
#
# [1173 rows x 6 columns]

# %%
#ticker_data_slice = ticker_data_grp.loc[2019,4,12]

eth_news_train = eth_news_combined.loc[2021-3-1:2021-5-31]
eth_news_train
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-0bc8238e9da8> in <module>
#       1 #ticker_data_slice = ticker_data_grp.loc[2019,4,12]
#       2
# ----> 3 eth_news_train = eth_news_combined.loc[2021-3-1:2021-5-31]
#       4 eth_news_train
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1865         if isinstance(key, slice):
#    1866             self._validate_key(key, axis)
# -> 1867             return self._get_slice_axis(key, axis=axis)
#    1868         elif com.is_bool_indexer(key):
#    1869             return self._getbool_axis(key, axis=axis)
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\indexing.py in _get_slice_axis(self, slice_obj, axis)
#    1531         labels = obj._get_axis(axis)
#    1532         indexer = labels.slice_indexer(slice_obj.start, slice_obj.stop,
# -> 1533                                        slice_obj.step, kind=self.name)
#    1534
#    1535         if isinstance(indexer, slice):
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\indexes\base.py in slice_indexer(self, start, end, step, kind)
#    4671         """
#    4672         start_slice, end_slice = self.slice_locs(start, end, step=step,
# -> 4673                                                  kind=kind)
#    4674
#    4675         # return a slice
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\indexes\base.py in slice_locs(self, start, end, step, kind)
#    4870         start_slice = None
#    4871         if start is not None:
# -> 4872             start_slice = self.get_slice_bound(start, 'left', kind)
#    4873         if start_slice is None:
#    4874             start_slice = 0
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\indexes\base.py in get_slice_bound(self, label, side, kind)
#    4796         # For datetime indices label may be a string that has to be converted
#    4797         # to datetime boundary according to its resolution.
# -> 4798         label = self._maybe_cast_slice_bound(label, side, kind)
#    4799
#    4800         # we need to look up the label
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\indexes\base.py in _maybe_cast_slice_bound(self, label, side, kind)
#    4748         # this is rejected (generally .loc gets you here)
#    4749         elif is_integer(label):
# -> 4750             self._invalid_indexer('slice', label)
#    4751
#    4752         return label
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\indexes\base.py in _invalid_indexer(self, form, key)
#    3065                         "indexers [{key}] of {kind}".format(
#    3066                             form=form, klass=type(self), key=key,
# -> 3067                             kind=type(key)))
#    3068
#    3069     # --------------------------------------------------------------------
#
# TypeError: cannot do slice indexing on <class 'pandas.core.indexes.base.Index'> with these indexers [2017] of <class 'int'>

# %%
X = eth_bull_news_df["compound"].values
y = eth_bull_news_df["market"].values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train)

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Kelsey\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
analyzer = SentimentIntensityAnalyzer()

# %%
y_vader_pred = []
y_vader_prob = []

# %%
for comment in X_test:
    y_vader_prob.append(analyzer.polarity_scores(comment)["pos"])
    sentiment_score = analyzer.polarity_scores(comment)["compound"]
    if sentiment_score >= 0.1:
        y_vader_pred.append(1)
    else:
        y_vader_pred.append(0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-b1c689a6bbb0> in <module>
#       1 for comment in X_test:
# ----> 2     y_vader_prob.append(analyzer.polarity_scores(comment)["pos"])
#       3     sentiment_score = analyzer.polarity_scores(comment)["compound"]
#       4     if sentiment_score >= 0.1:
#       5         y_vader_pred.append(1)
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\nltk\sentiment\vader.py in polarity_scores(self, text)
#     359         # text, words_and_emoticons, is_cap_diff = self.preprocess(text)
#     360         sentitext = SentiText(text, self.constants.PUNC_LIST,
# --> 361                               self.constants.REGEX_REMOVE_PUNCTUATION)
#     362         sentiments = []
#     363         words_and_emoticons = sentitext.words_and_emoticons
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\nltk\sentiment\vader.py in __init__(self, text, punc_list, regex_remove_punctuation)
#     268     def __init__(self, text, punc_list, regex_remove_punctuation):
#     269         if not isinstance(text, str):
# --> 270             text = str(text.encode("utf-8"))
#     271         self.text = text
#     272         self.PUNC_LIST = punc_list
#
# AttributeError: 'numpy.float64' object has no attribute 'encode'

# %%
# Option 1: Normalizing data using MinMaxScaler from sklearn
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(np.array(y_vader_prob).reshape(-1,1))
y_vader_prob_norm = scaler.transform(np.array(y_vader_prob).reshape(-1,1))
y_vader_prob_norm[:5]
# Out:
# array([[0.09937888],
#        [0.23602484],
#        [0.11180124],
#        [0.25465839],
#        [0.09937888]])

# %%
# Option 2: Using a comprehension list
normalized = [(x - min(y_vader_prob)) / (max(y_vader_prob) - min(y_vader_prob))
              for x in y_vader_prob]
normalized[:5]
# Out:
# [0.09937888198757763,
#  0.2360248447204969,
#  0.11180124223602483,
#  0.2546583850931677,
#  0.09937888198757763]

# %%
# Import the Tokenizer method from Keras
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
# Create an instance of the Tokenizer and fit it with the X text data
tokenizer = Tokenizer(lower=True)
tokenizer.fit_on_texts(X)

# %%
# Print the first five elements of the encoded vocabulary
for token in list(tokenizer.word_index)[:5]:
    print(f"word: '{token}', token: {tokenizer.word_index[token]}")
# Out:
# word: 'the', token: 1
# word: 'and', token: 2
# word: '0', token: 3
# word: 'or', token: 4
# word: 'traded', token: 5

# %%
# Transform the text data to numerical sequences
X_seq = tokenizer.texts_to_sequences(X)

# %%
# Contrast a sample numerical sequence with its text version
print("**Text comment**")
print({X[0]})
# Out:
# **Text comment**
# {'Please opt-in to receive news and information about Nasdaqs services.\nIf you do not opt-in you will not receive any emails from Nasdaq.\nYes!  I would like to receive Nasdaq communications related to Products, Industry News and Events.\nYou can always change your preferences or unsubscribe and your contact information is covered by our Privacy Policy.\nelq_hp\n*\nvar dom1 = document.querySelector(\'#form1783 #field1\');var field1 = new LiveValidation(dom1, {validMessage: "", onlyOnBlur: false, wait: 300});field1.add(Validate.Presence, {failureMessage:"This field is required"});field1.add(Validate.Format, {pattern: /(^[A-Z0-9!#$%&\'\\*\\+\\-\\/=\\?\\^_`\\{\\|\\}~][A-Z0-9!#$%&\'\\*\\+\\-\\/=\\?\\^_`\\{\\|\\}~\\.]{0,62}@(([A-Z0-9](?:[A-Z0-9\\-]{0,61}[A-Z0-9])?)(\\.[A-Z0-9](?:[A-Z0-9\\-]{0,61}[A-Z0-9])?)+)$)/i, failureMessage: "A valid email address is required"});field1.add(Validate.Format, {pattern: /\\.\\.|\\.@/i, failureMessage: "A valid email address is required", negate: "true"});var dom2 = document.querySelector(\'#form1783 #field2\');var field2 = new LiveValidation(dom2, {validMessage: "", onlyOnBlur: false, wait: 300});field2.add(Validate.Presence, {failureMessage:"This field is required"});var dom5 = document.querySelector(\'#form1783 #field5\');var field5 = new LiveValidation(dom5, {validMessage: "", onlyOnBlur: false, wait: 300});field5.add(Validate.Custom, {against: function(value) {return !value.match(/(telnet|ftp|https?):\\/\\/(?:[a-z0-9][a-z0-9-]{0,61}[a-z0-9]\\.|[a-z0-9]\\.)+[a-z]{2,63}/i);}, failureMessage: "Value must not contain any URL\'s"});field5.add(Validate.Presence, {failureMessage:"This field is required"});field5.add(Validate.Length, {tooShortMessage:"Invalid length for field value", tooLongMessage: "Invalid length for field value",  minimum: 4, maximum: 4});function handleFormSubmit(ele) { var submitButton = ele.querySelector(\'input[type=submit]\'); var spinner = document.createElement(\'span\'); spinner.setAttribute(\'class\', \'loader\'); submitButton.setAttribute(\'disabled\', true); submitButton.style.cursor = \'wait\'; submitButton.parentNode.appendChild(spinner); return true; }function resetSubmitButton(e){ var submitButtons = e.target.form.getElementsByClassName(\'submit-button\'); for(var i=0;i<submitButtons.length;i++){  submitButtons[i].disabled = false; }  }function addChangeHandler(elements){  for(var i=0; i<elements.length; i++){   elements[i].addEventListener(\'change\', resetSubmitButton); }  }var form = document.getElementById(\'form1783\'); addChangeHandler(form.getElementsByTagName(\'input\')); addChangeHandler(form.getElementsByTagName(\'select\')); addChangeHandler(form.getElementsByTagName(\'textarea\'));var nodes = document.querySelectorAll(\'#form1783 input[data-subscription]\');  if (nodes) { for (var i = 0, len = nodes.length; i < len; i++) {var status = nodes[i].dataset ? nodes[i].dataset.subscription : nodes[i].getAttribute(\'data-subscription\'); if(status ===\'true\') {nodes[i].checked = true;}}};var nodes = document.querySelectorAll(\'#form1783 select[data-value]\');   if (nodes) { for (var i = 0; i < nodes.length; i++) { var node = nodes[i]; var selectedValue = node.dataset ? node.dataset.value : node.getAttribute(\'data-value\'); if (selectedValue) { for (var j = 0; j < node.options.length; j++) { if(node.options[j].value === selectedValue) { node.options[j].selected = \'selected\';break;}}}}}\nThanks for submitting!'}

# %%
print("**Numerical sequence representation**")
print(X_seq[0])
# Out:
# **Numerical sequence representation**
# [1122, 1936, 17, 10, 43, 41, 2, 260, 125, 3876, 727, 211, 188, 272, 55, 1936, 17, 188, 165, 55, 43, 194, 1754, 141, 2225, 3877, 292, 353, 354, 10, 43, 2225, 3878, 68, 10, 703, 913, 41, 2, 2226, 188, 25, 1578, 492, 71, 3879, 4, 3880, 2, 71, 2227, 260, 9, 2228, 124, 372, 1057, 599, 3881, 3882, 463, 2514, 876, 1579, 778, 1362, 3883, 463, 1580, 146, 1937, 2514, 1938, 1939, 600, 1466, 579, 1580, 833, 834, 1940, 1209, 112, 1058, 9, 877, 1580, 833, 834, 2515, 804, 15, 704, 82, 778, 15, 704, 82, 778, 3, 779, 15, 704, 82, 15, 704, 82, 3, 464, 15, 704, 82, 15, 704, 82, 15, 704, 82, 3, 464, 15, 704, 82, 292, 1209, 15, 950, 92, 89, 9, 877, 1580, 833, 834, 2515, 804, 292, 1209, 15, 950, 92, 89, 9, 877, 3162, 512, 463, 2516, 876, 1579, 778, 1362, 3884, 463, 2517, 146, 1937, 2516, 1938, 1939, 600, 1466, 579, 2517, 833, 834, 1940, 1209, 112, 1058, 9, 877, 463, 2518, 876, 1579, 778, 1362, 3885, 463, 1581, 146, 1937, 2518, 1938, 1939, 600, 1466, 579, 1581, 833, 834, 2519, 8, 780, 234, 756, 234, 3886, 3887, 3888, 1286, 15, 704, 82, 15, 704, 82, 3, 464, 15, 704, 82, 15, 704, 82, 15, 3889, 29, 454, 292, 1209, 234, 914, 55, 3163, 194, 3890, 1581, 833, 834, 1940, 1209, 112, 1058, 9, 877, 1581, 833, 834, 951, 3891, 2520, 951, 16, 1058, 234, 3892, 2520, 951, 16, 1058, 234, 1941, 40, 1582, 40, 780, 3893, 1583, 463, 1584, 1583, 1579, 3894, 805, 2521, 778, 463, 1942, 876, 3895, 3896, 1942, 2522, 3897, 3898, 1584, 2522, 3899, 512, 1584, 757, 3900, 3901, 1584, 3902, 3903, 1942, 756, 512, 780, 2523, 244, 463, 1943, 244, 915, 629, 3904, 3905, 3906, 16, 463, 292, 3, 292, 1943, 951, 292, 1943, 292, 2524, 600, 780, 1585, 1944, 16, 463, 292, 3, 292, 1944, 951, 292, 1944, 292, 3907, 3908, 2523, 463, 629, 876, 3909, 3910, 1585, 629, 1945, 3911, 1585, 629, 1945, 3912, 1585, 629, 1945, 3913, 463, 524, 876, 2525, 778, 1362, 3914, 281, 2229, 778, 211, 524, 16, 463, 292, 3, 2526, 524, 951, 292, 2526, 292, 463, 2527, 524, 292, 1586, 524, 292, 1586, 2229, 524, 292, 2528, 2529, 3915, 211, 2527, 3916, 524, 292, 3917, 512, 463, 524, 876, 2525, 778, 1362, 2530, 281, 234, 778, 211, 524, 16, 463, 292, 3, 292, 524, 951, 292, 463, 835, 524, 292, 463, 1946, 835, 1586, 835, 1586, 234, 835, 2528, 2529, 3918, 211, 1946, 16, 463, 1287, 3, 1287, 835, 1363, 951, 1287, 211, 835, 1363, 1287, 234, 1946, 835, 1363, 1287, 1364, 3919, 728, 2531, 16, 3920]

# %%
# Import the pad_sequences method from Keras
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# Set the pad size
max_words = 140

# Pad the sequences using the pad_sequences() method
X_pad = pad_sequences(X_seq, maxlen=max_words, padding="post")

# %%
# Creating training, validation, and testing sets using the encoded data
X_train_rnn, X_test_rnn, y_train_rnn, y_test_rnn = train_test_split(X_pad, y)

X_train_rnn, X_val_rnn, y_train_rnn, y_val_rnn = train_test_split(X_train_rnn, y_train_rnn)

# %%
# Import Keras modules for model creation
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# %%
# Model set-up
vocabulary_size = len(tokenizer.word_counts.keys()) + 1
embedding_size = 64

# %%
# Define the LSTM RNN model
model = Sequential()

# Layer 1
model.add(Embedding(vocabulary_size, embedding_size, input_length=max_words))

# Layer 2
model.add(LSTM(units=280))

# Output layer
model.add(Dense(units=1, activation="sigmoid"))

# %%
# Compile the model
model.compile(
    loss="binary_crossentropy",
    optimizer="adam",
    metrics=[
        "accuracy",
        tf.keras.metrics.TruePositives(name="tp"),
        tf.keras.metrics.TrueNegatives(name="tn"),
        tf.keras.metrics.FalsePositives(name="fp"),
        tf.keras.metrics.FalseNegatives(name="fn"),
        tf.keras.metrics.Precision(name="precision"),
        tf.keras.metrics.Recall(name="recall"),
        tf.keras.metrics.AUC(name="auc"),
    ],
)

# %%
# Show model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 140, 64)           608704
# _________________________________________________________________
# lstm (LSTM)                  (None, 280)               386400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 281
# =================================================================
# Total params: 995,385
# Trainable params: 995,385
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Training the model
batch_size = 1000
epochs = 10
model.fit(
    X_train_rnn,
    y_train_rnn,
    validation_data=(X_val_rnn, y_val_rnn),
    epochs=epochs,
    batch_size=batch_size,
    verbose=1,
)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 5s 5s/step - loss: 0.6934 - accuracy: 0.0000e+00 - tp: 259.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 24.0000 - precision: 1.0000 - recall: 0.9152 - auc: 0.0000e+00 - val_loss: 0.6869 - val_accuracy: 0.0105 - val_tp: 0.0000e+00 - val_tn: 1.0000 - val_fp: 0.0000e+00 - val_fn: 94.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.1223
# Epoch 2/10
# 1/1 [==============================] - 1s 1s/step - loss: 0.6889 - accuracy: 0.0000e+00 - tp: 0.0000e+00 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 283.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.0000e+00 - val_loss: 0.6803 - val_accuracy: 0.0105 - val_tp: 0.0000e+00 - val_tn: 1.0000 - val_fp: 0.0000e+00 - val_fn: 94.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.1968
# Epoch 3/10
# 1/1 [==============================] - 1s 1s/step - loss: 0.6842 - accuracy: 0.0000e+00 - tp: 0.0000e+00 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 283.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.0000e+00 - val_loss: 0.6720 - val_accuracy: 0.0105 - val_tp: 0.0000e+00 - val_tn: 1.0000 - val_fp: 0.0000e+00 - val_fn: 94.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.2021
# Epoch 4/10
# 1/1 [==============================] - 1s 1s/step - loss: 0.6784 - accuracy: 0.0000e+00 - tp: 0.0000e+00 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 283.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.0000e+00 - val_loss: 0.6606 - val_accuracy: 0.0105 - val_tp: 0.0000e+00 - val_tn: 1.0000 - val_fp: 0.0000e+00 - val_fn: 94.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.1436
# Epoch 5/10
# 1/1 [==============================] - 2s 2s/step - loss: 0.6713 - accuracy: 0.0000e+00 - tp: 0.0000e+00 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 283.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.0000e+00 - val_loss: 0.6461 - val_accuracy: 0.0105 - val_tp: 0.0000e+00 - val_tn: 1.0000 - val_fp: 0.0000e+00 - val_fn: 94.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.1330
# Epoch 6/10
# 1/1 [==============================] - 1s 1s/step - loss: 0.6680 - accuracy: 0.0000e+00 - tp: 0.0000e+00 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 283.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.0000e+00 - val_loss: 0.6458 - val_accuracy: 0.0105 - val_tp: 0.0000e+00 - val_tn: 1.0000 - val_fp: 0.0000e+00 - val_fn: 94.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.1277
# Epoch 7/10
# 1/1 [==============================] - 1s 1s/step - loss: 0.6611 - accuracy: 0.0000e+00 - tp: 0.0000e+00 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 283.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.0000e+00 - val_loss: 0.6452 - val_accuracy: 0.0105 - val_tp: 0.0000e+00 - val_tn: 1.0000 - val_fp: 0.0000e+00 - val_fn: 94.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.1223
# Epoch 8/10
# 1/1 [==============================] - 1s 1s/step - loss: 0.6557 - accuracy: 0.0000e+00 - tp: 0.0000e+00 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 283.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.0000e+00 - val_loss: 0.6424 - val_accuracy: 0.0105 - val_tp: 1.0000 - val_tn: 1.0000 - val_fp: 0.0000e+00 - val_fn: 93.0000 - val_precision: 1.0000 - val_recall: 0.0106 - val_auc: 0.1223
# Epoch 9/10
# 1/1 [==============================] - 1s 1s/step - loss: 0.6494 - accuracy: 0.0000e+00 - tp: 7.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 276.0000 - precision: 1.0000 - recall: 0.0247 - auc: 0.0000e+00 - val_loss: 0.6372 - val_accuracy: 0.0105 - val_tp: 3.0000 - val_tn: 1.0000 - val_fp: 0.0000e+00 - val_fn: 91.0000 - val_precision: 1.0000 - val_recall: 0.0319 - val_auc: 0.1117
# Epoch 10/10
# 1/1 [==============================] - 1s 1s/step - loss: 0.6402 - accuracy: 0.0000e+00 - tp: 43.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 240.0000 - precision: 1.0000 - recall: 0.1519 - auc: 0.0000e+00 - val_loss: 0.6306 - val_accuracy: 0.0000e+00 - val_tp: 13.0000 - val_tn: 0.0000e+00 - val_fp: 1.0000 - val_fn: 81.0000 - val_precision: 0.9286 - val_recall: 0.1383 - val_auc: 0.1011

# %%
# Predict classes using the testing data
y_rnn_pred = model.predict_classes(X_test_rnn, batch_size=1000)
# Out:
# C:\Users\Kelsey\anaconda3\envs\pyvizenv\lib\site-packages\tensorflow\python\keras\engine\sequential.py:455: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
# Accuracy
from sklearn.metrics import accuracy_score

#print("Vader Accuracy: %.2f" % (accuracy_score(y_test, y_vader_pred)))
#print("RNN LSTM Accuracy %.2f" % (accuracy_score(y_test_rnn, y_rnn_pred)))

# %%
# Import the confusion_matrix method from sklearn
from sklearn.metrics import confusion_matrix

# %%
# Confusion matrtix metrics from Vader
tn_vader, fp_vader, fn_vader, tp_vader = confusion_matrix(y_test, y_vader_pred).ravel()

# Dataframe to display confusion matrix from Vader
cm_vader_df = pd.DataFrame(
    {
        "Positive(1)": [f"TP={tp_vader}", f"FP={fp_vader}"],
        "Negative(0)": [f"FN={fn_vader}", f"TN={tn_vader}"],
    },
    index=["Positive(1)", "Negative(0)"],
)
cm_vader_df.index.name = "Actual"
cm_vader_df.columns.name = "Predicted"
print("Confusion Matrix from Vader")
display(cm_vader_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-73dd1cf9a4cd> in <module>
#       1 # Confusion matrtix metrics from Vader
# ----> 2 tn_vader, fp_vader, fn_vader, tp_vader = confusion_matrix(y_test, y_vader_pred).ravel()
#       3
#       4 # Dataframe to display confusion matrix from Vader
#       5 cm_vader_df = pd.DataFrame(
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\sklearn\metrics\_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     274
#     275     """
# --> 276     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     277     if y_type not in ("binary", "multiclass"):
#     278         raise ValueError("%s is not supported" % y_type)
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      89     if len(y_type) > 1:
#      90         raise ValueError("Classification metrics can't handle a mix of {0} "
# ---> 91                          "and {1} targets".format(type_true, type_pred))
#      92
#      93     # We can't have more than one value on y_type => The set is no more needed
#
# ValueError: Classification metrics can't handle a mix of continuous and binary targets

# %%
# Confusion matrtix metrics from the RNN LSTM model
tn_rnn, fp_rnn, fn_rnn, tp_rnn = confusion_matrix(y_test_rnn, y_rnn_pred).ravel()

# Dataframe to display confusion matrix from the RNN LSTM model
cm_rnn_df = pd.DataFrame(
    {
        "Positive(1)": [f"TP={tp_rnn}", f"FP={fp_rnn}"],
        "Negative(0)": [f"FN={fn_rnn}", f"TN={tn_rnn}"],
    },
    index=["Positive(1)", "Negative(0)"],
)
cm_rnn_df.index.name = "Actual"
cm_rnn_df.columns.name = "Predicted"
print("Confusion Matrix from the RNN LSTM Model")
display(cm_rnn_df)

# %%
# Import the classification_report method from sklearn
from sklearn.metrics import classification_report

# %%
# Display classification report for Vader
print("Classification Report for Vader")
print(classification_report(y_vader_pred, y_test))

# %%
# Display classification report for the RNN LSTM Model
print("Classification Report for the RNN LSTM Model")
print(classification_report(y_rnn_pred, y_test_rnn))
