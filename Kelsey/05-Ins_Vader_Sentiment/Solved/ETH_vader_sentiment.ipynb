# %% [markdown]
# # Instructor Do: Intro to VADER Sentiment

# %%
# Initial imports
import os
from pathlib import Path
import pandas as pd
from newsapi import NewsApiClient
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Download/Update the VADER Lexicon
nltk.download('vader_lexicon')

# Initialize the VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Kelsey\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Reading the News API key enviroment variable
api_key = os.getenv("news_api")

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch all the news about Facebook Libra
eth_headlines = newsapi.get_everything(
    q="Ethereum OR ETH",
    language="en",
    page_size=20,
    sort_by="relevancy"
   # from_param="2021-01-01",
   # to="2021-07-20"
)

# Print total articles
print(f"Total articles about Ethereum: {eth_headlines['totalResults']}")

# Show sample article
eth_headlines["articles"][0]
# Out:
# Total articles about Ethereum: 2935
# {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#  'author': 'Connie Loizos',
#  'title': 'Crypto investors like Terraform Labs so much, they’re committing $150 million to its ‘ecosystem’',
#  'description': 'There are many blockchain platforms competing for investors’ and developers’ attention right now, from the big daddy of them all, Ethereum, to so-called “Ethereum Killers” like Solana, which we wrote about in May. Often, these technologies are seen as so prom…',
#  'url': 'http://techcrunch.com/2021/07/16/crypto-investors-like-terraform-labs-so-much-theyre-committing-150-million-to-its-ecosystem/',
#  'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/06/GettyImages-1174590894.jpg?w=667',
#  'publishedAt': '2021-07-16T16:00:55Z',
#  'content': 'There are many blockchain platforms competing for investors’ and developers’ attention right now, from the big daddy of them all, Ethereum, to so-called “Ethereum Killers” like Solana, which we wrote… [+2563 chars]'}

# %%
# Create the Facebook Libra sentiment scores DataFrame
eth_sentiments = []

for article in eth_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        eth_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
eth_df = pd.DataFrame(eth_sentiments)
#eth_df.set_index(eth_df["date"], inplace=True)
#eth_df.drop(columns=['date'], inplace=True)
#eth_df.sort_index(inplace=True)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
eth_df = eth_df[cols]


eth_df
# Out:
#           date                                               text  compound  \
# 0   2021-07-16  There are many blockchain platforms competing ...    0.3612
# 1   2021-07-29  Blockchain infrastructure startups are heating...   -0.2411
# 2   2021-07-14  While retail investors grew more comfortable b...    0.7264
# 3   2021-07-16  ETHEREUM: THE INFINITE GARDEN is a “feature-le...    0.6486
# 4   2021-07-27  Cryptocurrencies spiked Monday after Amazon li...    0.3400
# 5   2021-07-02  Bitcoin and Ethereum\r\nYuriko Nakao\r\nEther ...    0.3612
# 6   2021-07-23  Indicted Ethereum Foundation developer Virgil ...    0.1027
# 7   2021-07-17  "Anthony Di Iorio, a co-founder of the Ethereu...    0.6369
# 8   2021-07-30  Representations of cryptocurrency Ethereum are...    0.0000
# 9   2021-07-05  Ether holders have "staked" more than $13 bill...    0.7717
# 10  2021-07-05  Ether is the cryptocurrency of the ethereum ne...    0.6249
# 11  2021-07-29  All the sessions from Transform 2021 are avail...    0.0000
# 12  2021-07-26  This article was translated from our Spanish e...   -0.3400
# 13  2021-07-02  Major upgrades to the ethereum network could h...    0.4019
# 14  2021-07-27  Shopify has made it possible for eligible sell...    0.0000
# 15  2021-07-21  Personal Finance Insider writes about products...    0.5346
# 16  2021-07-24  The world of Non-Fungible Tokens (NFTs) offers...    0.4215
# 17  2021-07-15  This article was translated from our Spanish e...    0.2500
# 18  2021-07-15  After a successful testnet deployement, the Lo...    0.5267
# 19  2021-06-29  By Reuters Staff\r\nFILE PHOTO: Representation...    0.0000
#
#     positive  negative  neutral
# 0      0.075     0.000    0.925
# 1      0.000     0.061    0.939
# 2      0.164     0.000    0.836
# 3      0.175     0.000    0.825
# 4      0.105     0.000    0.895
# 5      0.110     0.041    0.849
# 6      0.043     0.000    0.957
# 7      0.157     0.000    0.843
# 8      0.000     0.000    1.000
# 9      0.194     0.000    0.806
# 10     0.150     0.000    0.850
# 11     0.000     0.000    1.000
# 12     0.000     0.072    0.928
# 13     0.080     0.000    0.920
# 14     0.000     0.000    1.000
# 15     0.158     0.000    0.842
# 16     0.088     0.000    0.912
# 17     0.123     0.067    0.810
# 18     0.149     0.069    0.782
# 19     0.000     0.000    1.000

# %%
eth_df.dtypes
# Out:
# date        datetime64[ns]
# text                object
# compound           float64
# positive           float64
# negative           float64
# neutral            float64
# dtype: object

# %%
# Get descriptive stats from the DataFrame
eth_df.describe()
# Out:
#          compound    positive    negative     neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.145841    0.056930    0.022600    0.920450
# std      0.355997    0.063974    0.045436    0.073079
# min     -0.812600    0.000000    0.000000    0.714000
# 25%      0.000000    0.000000    0.000000    0.867750
# 50%      0.000000    0.051000    0.000000    0.926500
# 75%      0.426225    0.101250    0.033250    1.000000
# max      0.840200    0.237000    0.249000    1.000000
